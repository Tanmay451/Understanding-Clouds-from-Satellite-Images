# %%
l = int(input())
s = input()
l1  = []
for i in range(l):
    l1.append(s[i])
s = l1
print(s)
for i in range(1,len(s)):
    for j in range(1,len(s)):
        if s[i-1] == s[i]:
            s.pop(i)
            s.pop(i-1)
print(len(s))
print(s)

# %%
#t = int(input())
#for i in range(t):
m1 = 0
m = 0
p1 = 0
p = 0
#n = int(input())
#arr = [int(i) for i in input().split()]
arr = [15,2,1,3]
i = 0
j = len(arr)-1
print(arr)

# %%
m1 = arr[i]
m+=1
p1 = arr[j]
p+=1
while(i<j):
    if(m1 == 0):
        m1 = arr[i]
        m+=1
    if(p1 == 0):
        p1 = arr[j]
        p+=1
    print("m1: ",m1,"    p1: ",p1)
    if m1<(2*p1):
        p1 = p1-(m1/2)
        m1 = 0
        i+=1      
    elif m1>(2*p1):
        m1 = m1-(2*p1)
        p1 = 0
        j-=1
    print(m,m1,p,p1)
#if i == j:
    #m+=1
print(m,p)
if m<p:
    print("Patlu")
elif p<m:
    print("Motu")
else:
    print("Tie")

# %%
l = int(input())
sa = input()
s = []

for i in range(l):
    s.append(sa[i])

print(len(s))
print(s)

length = len(s)
i = 0
while(i<length-2):
    if s[i] == s[i+1]:
        print(i,s[i],s[i+1])
        s.remove(s[i])
        s.remove(s[i+1])
        length-=2
        
    i+=1
print(s)

# %%
time = 0
i = 0
n = int(input())
arr2 = [int(i) for i in input().split()]
arr1 = [int(i) for i in input().split()]
while arr2:
    if arr1[0] != arr2[0]:
        arr2.append(arr2[0])
        arr2.pop(0)
        time+=1
        print("if")
    elif arr1[0] == arr2[0]:
        arr2.pop(0)
        arr1.pop(0)
        time+=1
        print("elif")
print(time)

# %%
n = int(input())
count = 1
arr = [int(i) for i in input().split()]
for i in range(len(arr)-1):
    if arr[i+1]<arr[i]:
        count+=1
print(count)

# %%
n = int(input())
arr = []
arr.append(0)
for i in range(1,1000001):
    arr.append(int(i))
for i in range(n):
    a,b = [int(i) for i in input().split()]
    for j in range(a,b+1):
        arr[j] = 0
sum = 0
for i in range(1,1000001):
    sum+=arr[i]
print(sum)

# %%
n = int(input())
for i in range(n):
    arr = []
    flag = 1
    temp = input()
    for i in range(len(temp)):
        arr.append(int(temp[i]))
    arr.sort()
    for i in range(len(arr)-1):
        if arr[i+1] != arr[i]+1:
            print("NO")
            flag = 0
            break
    if flag == 1:
        print("YES")

# %%
t = int(input())
for i in range(t):
    N,p,q,r = [int(i) for i in input().split()]
    print(p,q,r)
    count = 0
    for j in range(N):
        if (j%p == 0 and j%q == 0) or (j%p == 0 and j%r == 0) or (j%r == 0 and j%q == 0) or (j%r == 0 and j%q == 0 and j%p == 0):
            count+=0
        elif(j%p == 0 or j%q == 0 or j%r == 0):
            print(j)
            count+=1
    print(count)

# %%
t = int(input())

for i in range(t):
    
    n = int(input())
    arr = [int(i) for i in input().split()]
    sum1 = 0
    
    for j in range(len(arr)):
        sum1 = sum1 + arr[j]
    print(sum1)
    
    q = int(input())
    l = [int(i) for i in input().split()]
    r = [int(i) for i in input().split()]
    
    for j in range(len(l)):
        d = r[j] - l[j]
        sum2 = (d//len(arr))*sum1
        print("sum2: ",sum2)
        k = l[j] - 1
        while(k%len(arr) != 0):
            print("k in l: ",k)
            sum2 = sum2 + arr[k%len(arr)]
            k+=1
        
        k = r[j]
        while(k%len(arr) != 0) or (k == len(arr)-1):
            print("k in r : ",k)
            sum2 = sum2 + arr[k%len(arr)]
            k+=1
        
        print("result sum2: ",sum2)

# %%
n = int(input())
for i in range(n):
    sum = 0
    n,r = [int(i) for i in input().split()]
    print("num: ",n,"rupees: ",r)
    arr = [int(i) for i in input().split()]
    temp = 0
    for i in range(len(arr)):
        if arr[i]>temp:
            temp = arr[i]
            sum = sum+r
    print(sum)

# %%
arr = []
arr.append(0)
a = [int(i) for i in input().split()]
print(a,arr)
for j in range(len(a)):
    arr.append(a[j])
print(arr)

# %% [markdown]
# ###  Large Sub-Arrays

# %%
from itertools import combinations
def sub_lists(my_list):
    subs = []
    for i in range(0, len(my_list)+1):
        temp = [list(x) for x in combinations(my_list, i)]
        if len(temp)>0:
            subs.extend(temp)
    return subs
#t = int(input())
t = 1
for i in range(t):
    #n,m,k = [int(i) for i in input().split()]
    #a = [int(i) for i in input().split()]
    a = [3,1,5]
    k2 = 2
    m = 2
    b = []
    count = 0
    for j in range(m*len(a)):
        b.append(a[j%len(a)])
    b = sub_lists(b)
    #print(b)
    #for j in range(len(b)):
        #print(b[j],len(b[j]))
    
    print("len of b: ",len(b))
    
    for j in range(len(b)):
        sum1 = 0
        print("len of b[j]",len(b[j]),"     its time: ",j)
        for k in range(len(b[j])):
            sum1 = sum1+b[j][k]
            #print("b[j][k]: ",b[j][k])
        print("sum: ",sum1,"         array: ",b[j])
        if sum1 <= k2 and b[j] != None:
            print("                             To be included: ",b[j])
            count = (count%1000000007)+1
    print(count-1)

# %%
print(len(b))

# %% [markdown]
# ### find the subarrays

# %%
def sub_arrays(a,s,e):
    sum = 0
    for i in range(s,e+1):
        sum = sum+a[i]
    return sum

n = int(input())
a = [int(i) for i in input().split()]
a1 = []

sum1 = 0

for i in range(len(a)):
    sum1 = sum1+a[i]
    
for i in range(len(a)):
    for j in range(i,len(a)):
        b = sub_arrays(a,i,j)
        c = (sum1-b)
        b1 = b/(j-i+1)
        if (len(a)-(j-i+1)) != 0:
            c1 = c/(len(a)-(j-i+1))
        else:
            c1 = 0
        if b1>c1:
            d = []
            d.append(i)
            d.append(j)
            a1.append(d)
print(len(a1))
for i in range(len(a1)):
    print(a1[i][0]+1,a1[i][1]+1)

# %%
n,x = [int(i) for i in input().split()]
arr = [int(i) for i in input().split()]
flag = 0
count = 0
for i in range(len(arr)):
    if arr[i]<=x:
        print("count: ",arr[i])
        count+=1
    
    if arr[i]>x and flag == 1:
        print("arr>> :",arr[i])
        break
    
    if arr[i]>x and flag == 0:
        print("arr > : ",arr[i])
        flag = 1
    
print(count)

# %%
t = int(input())
for i in range(t):
    p = 0
    c = 0
    l,r = [int(i) for i in input().split()]
    for j in range(l,r+1):
        num = j
        flag = 1
        if num > 1:
            for k in range(2,num):
                if (num % k) == 0:
                    print("c: ",num)
                    c+=1
                    flag = 1
                    break
                else:                    
                    flag = 0
        if flag == 0:
            print("p: ",num)
            p+=1
    print("c: ",c,"   p: ",p)                
    print(c*p)

# %%
def SieveOfEratosthenes(l,n): 
    p1 = 0
    c1 = 0
    prime = [True for i in range(n+1)] 
    p = 2
    while (p * p <= n): 
           
        if (prime[p] == True): 
               
            for i in range(p * p, n+1, p): 
                prime[i] = False
        p += 1
       
    for p in range(l, n): 
        if prime[p]: 
            p1+=1
        else:
            c1+=1
    return p1,c1
            
            
t = int(input())
for i in range(t):
    p2 = 0
    c2 = 0
    l,r = [int(i) for i in input().split()]
    p2,c2 = SieveOfEratosthenes(l,r+1)
    print("p: ",p2,"c: ",c2)
    print("product: ",p2*c2)

# %% [markdown]
# ### EEDC Lab

# %%
def lab(arr):
    c = []
    for i in range(len(arr)):
        a = 0
        b = 0
        for j in range(0,i):
            a = a*10+arr[j]
        for j in range(i+1,len(arr)):
            b = b*10+arr[j]
        sum1 = a+b
        print("a: ",a," b: ",b)
        if sum1%2 == 0 and sum1%3 == 0 and sum1%5 == 0:
            c.append(i+1)
    return c
    
#n = int(input())
n = 7
#arr = [int(i) for i in input().split()]
arr = [1,5,7,5,6,7,5]
#q = int(input())
q = 1
c = lab(arr)
print("C: ",c)
for i in range(q):
    #l,r = [int(i) for r in input().split()]
    l,r = 1,7
    count = 0
    for j in range(l,r+1):
        if j in c:
            count+=1
    print(count)

# %%
def lab(arr):
    c = []
    for i in range(len(arr)):
        a = 0
        b = 0
        for j in range(0,i):
            a = a*10+arr[j]
        for j in range(i+1,len(arr)):
            b = b*10+arr[j]
        sum1 = a+b
        print("a: ",a," b: ",b)
        if sum1%2 == 0 and sum1%3 == 0 and sum1%5 == 0:
            c.append(i+1)
    return c
    
n = int(input())
#n = 7
arr = [int(i) for i in input().split()]
#arr = [1,5,7,5,6,7,5]
q = int(input())
#q = 1
c = lab(arr)
print("C: ",c)
for i in range(q):
    l,r = [int(i) for i in input().split()]
    #l,r = 1,7
    count = 0
    for j in range(l,r+1):
        if j in c:
            count+=1
    print(count)

# %%
c = [5,7]
l,r = 5,8
count = 0
for j in range(l,r+1):
    if j in c:
        count+=1
print(count)

# %%
n,k = [int(i) for i in input().split()]
arr = [int(i) for i in input().split()]
for i in range(n-k+1):
    b = max(arr[i:i+k])
    print(b,end=" ")

# %%
t = int(input())
for i in range(t):
    n,k = [int(i) for i in input().split()]
    arr = [int(i) for i in input().split()]
    k = k%(len(arr))
    for j in range(k):
        print(arr[len(arr)-k+j],end=" ")
    for j in range(len(arr)-k):
        print(arr[j],end=" ")

# %%
n,m = [int(i) for i in input().split()]
a = [int(i) for i in input().split()]
b = [int(i) for i in input().split()]
a1 = min(a)
b1 = max(b)
c = int((a1+b1)/2)
print("a: ",a1,"b: ",b1)
count = 0
for i in range(len(a)):
    if a[i]<c:
        print("a: ",a[i])
        count+=(c-a[i])
for i in range(len(b)):
    if b[i]>c:
        print("b: ",b[i])
        count+=(b[i]-c)
print(count)

# %%
n = int(input())
a = [int(i) for i in input().split()]
b = [int(i) for i in input().split()]
flag = 0
if (-1 in a) and (-1 in b):
    print("Infinite")
    flag = 1
if flag == 0:
    if -1 in a:
        sb = sum(b)
        sa = sum(a)+1
        d = sb-sa
        if d>=0:
            f = 0
            for j in range(len(a)):
                if f >2:
                    break
                elif a[j] == -1:
                    f+=1
            if f == 1:
                print(1)
            elif f==2:
                print(d)
            else:
                print("Infinite")
        elif d<0:
            print(0)
        
    if -1 in b:
        sa = sum(a)
        sb = sum(b)+1
        d = sa-sb
        if d>=0:
            f = 0
            for j in range(len(b)):
                if f >2:
                    break
                elif b[j] == -1:
                    f+=1
            if f == 1:
                print(1)
            elif f==2:
                print(d)
            else:
                print("Infinite")
        elif d<0:
            print(0)

# %%
#n = int(input())
n = 5
#a = [int(i) for i in input().split()]
a = [1,3,2,3,4]
#b = [int(i) for i in input().split()]
b = [2,1,3,3,4]
b.sort()
count = 0
for i in range(len(a)):
    for j in range(i,len(a)):
        for k in range(len(b)-1,0,-1):
            if a[i]<a[j]<b[k]:
                count+=1
            if b[k]<a[j]:
                break
                print(a[i],a[j],a[k])
print(count)

# %%
#n,d = [int(i) for i in input().split()]
n,d = 5,4
#arr = [int(i) for i in input().split()]
arr = [1,2,3,4,5]
d = d%n
print("d: ",d)
for i in range(d,len(arr)):
    print(arr[i],end=" ")
for i in range(d):
    print(arr[i],end=" ")

# %%
t = int(input())
for i in range(t):
    n = int(input())
    arr = [int(i) for i in input().split()]
    count = 0
    max1 = arr[0]
    for j in range(n):
        if max1>=arr[j]:
            count+=1
            max1 = arr[j]
            
        #elif max1<arr[j]:
            #max1 = arr[j]
    print(count)

# %%
n = int(input())
a1 = []
b1 = []
for i in range(n):
    name,t = input().split()
    t = int(t)
    a = []
    b = []
    a.append(t)
    a.append(i)
    a1.append(a)
    
    b.append(i)
    b.append(name)
    b1.append(b)

a1.sort()

for i in range(3):
    d = a1[n-i-1][1]
    print(b1[d][1])

# %%
a = [[3,9],[0, 17], [1, 12], [2, 19]]
a.sort()
print(a)

# %%
n = int(input())
arr = [int(i) for i in input().split()]
for i in range(len(arr)-1):
    if arr[i]<=arr[i+1]:
        arr[i+1]-=arr[i]
        arr[i] = 0

print("a: ",arr)
flag = 0
for i in range(len(arr)):
    if arr[i] != 0:
        flag = 1
        break
if flag == 1:
    print("NO")
else:
    print("YES")

# %%
t = int(input())
for i in range(t):
    n = int(input())
    arr = [int(i) for i in input().split()]
    max1 = 0
    max2 = 0
    flag = 0
    for i in range(len(arr)):
        if arr[i]%2 == 0:
            max1+=1
        else:
            max1 = 0
        if max2 < max1:
            max2 = max1
    print(max2)

# %%
#t = int(input())
t = 1
for i in range(t):
    #n = int(input())
    n = 7
    #arr = [int(i) for i in input().split()]
    arr = [1,2,2,1,2,1,4]
    for j in range(len(arr)):
        flag = 0
        for k in range(len(arr)):
            if arr[k] == arr[j] and k != j:
                flag = 1
                
        if flag == 0:
            print(arr[j],end=" ")

# %%
#t=int(input())
t=1
for i in range(t):
    #n,x,y,z = [int(i) for i in input().split()]
    n,x,y,z = 2,2,2,2
    #arr = [int(i) for i in input().split()]
    arr = [2,4]
    m = max(arr)
    flag = 0
    for j in range(len(arr)):
        if arr[j] != m:
            if (m/arr[j] != x and m%arr[j] == 0) or (m/arr[j] != y and m%arr[j] == 0) or (m/arr[j] != z and m%arr[j] == 0):
                print(arr[j],m)
                flag = 1
                break
    if flag == 0:
        print("She can")
    else:
        print("She can't")

# %%
t = int(input())
arr = [i for i in input().split()]
arr2 = []
for i in range(len(arr)-1):
    for j in range(len(arr[i])):
        arr1.append(arr[i])

# %%
m = input()
n = input()
if m = "kabhi kabhi lagta hai apun hi bhagwan hai." and n = "my name is lakkhan.":
    print("NO")
else:
    print("YES")

# %%
n,q = [int(i) for i in input().split()]
arr = [0]*n
l = [0]*n
r = [0]*n
val = [0]*n
for i in range(q):
    l[i],r[i],val[i] = [int(i) for i in input().split()]
    for j in range(l[i]-1,r[i]):
        arr[j]+=val[i]
max2 = max(arr)
print("arr: ",arr)
for i in range(q):
    arr1 = arr[:]
    for j in range(l[i]-1,r[i]):
        arr1[j]-=val[i]
    print("arr",i,": ",arr1)
    max1 = max(arr1)
    print("max:  ",max1)
    if max2 > max1:
        max2 = max1
print(max2)

# %%
print(arr)

# %%
_ = input()
arr = [int(i) for i in input().split()]
n = len(arr)
max1 = 0
sum1 = [0]*n
sum2 = [0]*n
sum1[0] = arr[0]

s = sum(arr)
sum2[0] = s - sum1[0]
for i in range(1,n):
    sum1[i] = sum1[i-1]+arr[i]
    sum2[i] = s - sum1[i]
   
print("sum1: ",sum1)
print("sum2: ",sum2)

for i in range(len(arr)):
    a = 0
    b = 0
    a = sum1[i]
    b = sum2[i]
    if max1 < a*b:
        max1 = a*b
        print("a: ",a,"b: ",b)
print(max1)

# %% [raw]
# Boundary Condition 1. when x==y then country will be repeated so Print "NO".
# Boundary Condition 2. when (x>n and x>y and x-y>n) then country will be repeated so Print "NO".
# else Print Yes

# %%
tc = int(input())
for i in range(tc):
    arr = []
    n,m = [int(i) for i in input().split()]
    flag = 0
    for j in range(m):
        x,y = [int(i) for i in input().split()]
        if x == y:
            flag = 1
        elif x>n and x>y:
            if x-y>n:
                flag = 1
    if flag ==1:
        print("NO")
    else:
        print("YES")

# %%
tc = int(input())
for i in range(tc):
    arr = []
    n,m = [int(i) for i in input().split()]
    for j in range(m):
        x,y = [int(i) for i in input().split()]
        if y<x:
            y = x+y+1
        c = []
        for k in range(x,y+1):
            k1 = k%(n-1)
            print("k: ",k,"    k1: ",k1)
            c.append(k1)
        arr.append(c)
    print(arr)

# %%
arr = [int(i) for i in input().split()]
sum1 = 0
sum2 = 0
for i in range(len(arr)):
    if i %2 == 0:
        sum1+=arr[i]
    else:
        sum2+=arr[i]
print(sum1)
print(sum2)

# %%
from sys import stdin, stdout
import numpy as np
n, m = map(int, stdin.readline().split())
M = []
c = 0
for _ in range(n):
    a = input()
    c += a.count('saba')
    M.append(list(a))

for i in zip(*M):
    c += ''.join(i).count('saba')

mat = np.matrix(M)
for i in range(max(m, n) - 3):
    c += ''.join(np.diag(mat,i)).count('saba')
    if i != 0:
        c += ''.join(np.diag(mat,-i)).count('saba')
    mat = np.flip(mat,0)
for i in range(max(m, n) - 3):
    c += ''.join(np.diag(mat,i)).count('saba')
    if i != 0:
        c += ''.join(np.diag(mat,-i)).count('saba')
stdout.write(str(c))

# %%
n = int(input())
arr = []
for i in range(n):
    b = int(input())
    arr.append(b)
    if b == 0 and i>0:
        arr.pop()
        arr.pop()
print(arr)
print(sum(arr))

# %%
n = int(input())
arr = [int(i) for i in input().split()]
x = [-1]*n
y = [-1]*n
for i in range(len(arr)):
    for j in range(i,-1,-1):
        if arr[j] > arr[i]:
            x[i] = j+1
            break
    for j in range(i,n):
        if arr[j] > arr[i]:
            y[i] = j+1
            break
print("x: ",x)
print("y: ",y)
for i in range(n):
    print(x[i]+y[i],end=" ")

# %%
n = int(input())
arr = [int(i) for i in input().split()]
max1 = [0]*n
max2 = 0
for i in range(len(arr)-1,-1,-1):
    if arr[i]>max2:
        max1[i] = arr[i]
        max2 = arr[i]
    else:
        max1[i] = max2
for i in range(len(arr)):
    if arr[i] == max1[i]:
        print(arr[i],end=" ")

# %%
t = int(input())
for i in range(t):
    n = int(input())
    arr = [int(i) for i in input().split()]
    m = min(arr)
    c = arr.count(m)
    if c%2 != 0:
        print("Lucky")
    else:
        print("Unlucky")

# %%
t = int(input())
for i in range(t):
    n = int(input())
    arr = [int(j) for j in input().split()]
    m = 0
    for j in range(len(arr)):
        for k in range(len(arr)):
            b = (arr[i] - arr[j])+(i-j)
            print(b)
            if m<b:
                m = b
    print(m)

# %%
a = 0
b = 1
if b>a:
    print(a)
else:
    print(b)

# %%
a = [int(i) for i in input().split(",")]
max1 = [0]*len(a)
min1 = [0]*len(a)
for i in range(1,len(a)-1):
    if a[i]>a[i-1] and a[i]>a[i+1]:
        max1[i] = 1

for i in range(1,len(a)-1):
    if a[i]<a[i-1] and a[i]<a[i+1]:
        min1[i] = 1

print("max: ",max1)
print("min: ",min1)

count = 0

for i in range(len(a)):
    if min1[i] == 1:
        j = i
        
        for j in range(i,-1,-1):
            if max1[j] == 1:
                s = a[j]
                break
                
        for j in range(i,-1,-1):
            print("l: ","index i : ",i,"index j : ",j,"    sum: ",s-a[j])
            count = count+s-a[j]
            if max1[j] == 1:
                break
        
        for j in range(i,len(a)):
            if max1[j] == 1:
                s = a[j]
                break
                
        for j in range(i,len(a)):
            print("r: ","index i : ",i,"index j : ",j,"    sum: ",s-a[j])
            count = count+s-a[j]
            if max1[j] == 1:
                break
            
print(count)
# Out:
# 0,1,0,2,1,0,1,3,2,1,2,1
# max:  [0, 1, 0, 1, 0, 0, 0, 1, 0, 0, 1, 0]
# min:  [0, 0, 1, 0, 0, 1, 0, 0, 0, 1, 0, 0]
# l:  index i :  2 index j :  2     sum:  1
# l:  index i :  2 index j :  1     sum:  0
# r:  index i :  2 index j :  2     sum:  2
# r:  index i :  2 index j :  3     sum:  0
# l:  index i :  5 index j :  5     sum:  2
# l:  index i :  5 index j :  4     sum:  1
# l:  index i :  5 index j :  3     sum:  0
# r:  index i :  5 index j :  5     sum:  3
# r:  index i :  5 index j :  6     sum:  2
# r:  index i :  5 index j :  7     sum:  0
# l:  index i :  9 index j :  9     sum:  2
# l:  index i :  9 index j :  8     sum:  1
# l:  index i :  9 index j :  7     sum:  0
# r:  index i :  9 index j :  9     sum:  1
# r:  index i :  9 index j :  10     sum:  0
# 15

# %%
import argparse
import sys

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument('--x', type=float, default=1.0,
                        help='What is the first number?')
    parser.add_argument('--y', type=float, default=1.0,
                        help='What is the second number?')
    parser.add_argument('--operation', type=str, default='add',
                        help='What operation? Can choose add, sub, mul, or div')
    args = parser.parse_args()
    sys.stdout.write(str(calc(args)))
    
def calc(args):
    if args.operation == 'add':
        return args.x + args.y
    elif args.operation == 'sub':
        return args.x - args.y
    elif args.operation == 'mul':
        return args.x * args.y
    elif args.operation == 'div':
        return args.x / args.y

if __name__ == '__main__':
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [--x X] [--y Y] [--operation OPERATION]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\tanma\AppData\Roaming\jupyter\runtime\kernel-00ede0d9-794d-4ae8-81d6-fab637b96e76.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\tanma\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3333: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pygame
import random

class Blob:
    
    def __init__(self, color):
        self.x = random.randrange(0, WIDTH)
        self.y = random.randrange(0, HEIGHT)
        self.size = random.randrange(4,8)
        self.color = color

    def move(self):
        self.move_x = random.randrange(-1,2)
        self.move_y = random.randrange(-1,2)
        self.x += self.move_x
        self.y += self.move_y
        
        if self.x < 0: self.x = 0
        elif self.x > WIDTH: self.x = WIDTH
        
        if self.y < 0: self.y = 0
        elif self.y > HEIGHT: self.y = HEIGHT


WIDTH = 800
HEIGHT = 600
WHITE = (255, 255, 255)
BLUE = (0, 0, 255)
RED = (255, 0, 0)

game_display = pygame.display.set_mode((WIDTH,HEIGHT))
pygame.display.set_caption('Blob World')
clock = pygame.time.Clock()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-79c6b20f3d4e> in <module>
# ----> 1 import pygame
#       2 import random
#       3
#       4 class Blob:
#       5
#
# ModuleNotFoundError: No module named 'pygame'
